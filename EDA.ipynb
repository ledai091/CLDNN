# %%
import numpy as np
import pandas as pd
import os
from glob import glob

# %%
df = pd.read_csv('/mnt/sdb2/DaiLe/CLDNN/img_resize/img_resize.csv')

# %%
df['length'] = [len(glob(os.path.join(i, '*.jpg'))) for i in df['img_path']]

# %%
len(df['img_path'][df['label'] == 0].tolist())
# Out:
# 29

# %%
filtered_df = df[df['label'] == 0][['img_path', 'length']]

# %%
filtered_df
# Out:
#                                           img_path  length
# 7      img_resize/Thang12/19_220427_well10_zid99_7     142
# 11   img_resize/Thang12/23_220485A_well09_zid99_11      32
# 13    img_resize/Thang12/26_220393_well11_zid99_13     140
# 14    img_resize/Thang12/27_220377_well04_zid99_14     140
# 16    img_resize/Thang12/32_220452_well04_zid99_16     140
# 18     img_resize/Thang12/8_220231_well02_zid99_18     170
# 19    img_resize/Thang12/9_220417A_well01_zid99_19     144
# 24      img_resize/Thang3/1_220013_well01_zid99_29     143
# 28      img_resize/Thang3/1_230054_well01_zid99_25     142
# 30        img_resize/Thang3/220013_well01_zid99_20     143
# 31        img_resize/Thang3/220134_well05_zid99_57     143
# 35       img_resize/Thang3/220417A_well04_zid99_61     144
# 38        img_resize/Thang3/220474_well02_zid99_65     142
# 41        img_resize/Thang3/230008_well04_zid99_21     147
# 51      img_resize/Thang3/2_220474_well02_zid99_30     142
# ...
