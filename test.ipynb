# %%
from glob import glob
import pandas as pd
import os

# %%
import cv2

# Path to the video file
video_path = '1.mp4'

# Open the video
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Frame rate of the video
frame_rate = cap.get(cv2.CAP_PROP_FPS)

# Interval of frames to capture
interval = int(frame_rate)  # Capturing an image every second

count = 0
frame_count = 0

while cap.isOpened():
    ret, frame = cap.read()

    # If read was successful
    if ret:
        # Save frame every 'interval' frames
        if frame_count % interval == 0:
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            cv2.imwrite(f'img/frame_{count}.jpg', gray)
            count += 1
        frame_count += 1
    else:
        break

# Release the video capture object
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread("img/frame_0.jpg")

# Convert BGR to RGB (OpenCV uses BGR by default)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display the image
plt.imshow(image_rgb, cmap='gray')
plt.axis('off')
plt.show()

# %%
height = 28
width = 28
resized_img = cv2.resize(image, (width, height))
plt.imshow(resized_img)

# %%
image.shape
# Out:
# (512, 512, 3)

# %%
image_gray.shape[0]
# Out:
# 512

# %%
def crop_center(img):
    height, width = img.shape[0], img.shape[1]
    mid_y = height//2
    mid_x = width//2
    img_resize = img[(mid_x-(mid_x//2)):(mid_x+(mid_x//2)), (mid_y-(mid_y//2)):(mid_y+(mid_y//2))]
    return img_resize

im = crop_center(image)
plt.imshow(im)

# %%
list_dir = glob('data/Phase1/*/**.mp4')

# %%
list_dir
# Out:
# ['data/Phase1/Thang12/10_220126_well02_zid99_NG T THANH HIỆP .mp4',
#  'data/Phase1/Thang12/11_220276A_well10_zid99_NG THI LAN .mp4',
#  'data/Phase1/Thang12/12_220450_well03_zid99_NG T THANH HUYỀN .mp4',
#  'data/Phase1/Thang12/13_220448_well02_zid99_PHẠM THUỲ DƯƠNG .mp4',
#  'data/Phase1/Thang12/14_220431_well02_zid99_HOÀNG HUYỀN TRANG .mp4',
#  'data/Phase1/Thang12/16_220484_well09_zid99_ĐỖ THU HẰNG .mp4',
#  'data/Phase1/Thang12/18_220471_well11_zid99_NGUYỄN THUÝ QUỲNH .mp4',
#  'data/Phase1/Thang12/19_220427_well10_zid99_TRẦN THỊ PHƯƠNG .mp4',
#  'data/Phase1/Thang12/1_220192_well07_zid99_ĐỒNG KIM ANH.mp4',
#  'data/Phase1/Thang12/20 _220381_well01_zid99_NG KIỀU TRINH 1.mp4',
#  'data/Phase1/Thang12/21_220425_well10_zid99_NGUYỄN THỊ QUYÊN .mp4',
#  'data/Phase1/Thang12/23_220485A_well09_zid99_ĐỊNH T VINH .mp4',
#  'data/Phase1/Thang12/25_220388_well08_zid99_CAO THỊ NGUYỆT .mp4',
#  'data/Phase1/Thang12/26_220393_well11_zid99_VŨ THỊ YẾN .mp4',
# ...

# %%
dict = {}
for i, dir in enumerate(list_dir):
    pattern_remove = dir.split('/')[-1].split('_')[-1]
    new_dir = dir.replace(pattern_remove, f"{i}.mp4")
    if '-' in new_dir:
        new_dir = new_dir.replace('-', '_')
    dict[dir] = new_dir
    print(new_dir)
# Out:
# data/Phase1/Thang12/10_220126_well02_zid99_0.mp4
# data/Phase1/Thang12/11_220276A_well10_zid99_1.mp4
# data/Phase1/Thang12/12_220450_well03_zid99_2.mp4
# data/Phase1/Thang12/13_220448_well02_zid99_3.mp4
# data/Phase1/Thang12/14_220431_well02_zid99_4.mp4
# data/Phase1/Thang12/16_220484_well09_zid99_5.mp4
# data/Phase1/Thang12/18_220471_well11_zid99_6.mp4
# data/Phase1/Thang12/19_220427_well10_zid99_7.mp4
# data/Phase1/Thang12/1_220192_well07_zid99_8.mp4
# data/Phase1/Thang12/20 _220381_well01_zid99_9.mp4
# data/Phase1/Thang12/21_220425_well10_zid99_10.mp4
# data/Phase1/Thang12/23_220485A_well09_zid99_11.mp4
# data/Phase1/Thang12/25_220388_well08_zid99_12.mp4
# data/Phase1/Thang12/26_220393_well11_zid99_13.mp4
# data/Phase1/Thang12/27_220377_well04_zid99_14.mp4
# data/Phase1/Thang12/28_220457_well09_zid99_15.mp4
# data/Phase1/Thang12/32_220452_well04_zid99_16.mp4
# data/Phase1/Thang12/33_220402_well09_zid99_17.mp4
# data/Phase1/Thang12/8_220231_well02_zid99_18.mp4
# ...

# %%
dict
# Out:
# {'data/Phase1/Thang12/10_220126_well02_zid99_NG T THANH HIỆP .mp4': 'data/Phase1/Thang12/10_220126_well02_zid99_0.mp4',
#  'data/Phase1/Thang12/11_220276A_well10_zid99_NG THI LAN .mp4': 'data/Phase1/Thang12/11_220276A_well10_zid99_1.mp4',
#  'data/Phase1/Thang12/12_220450_well03_zid99_NG T THANH HUYỀN .mp4': 'data/Phase1/Thang12/12_220450_well03_zid99_2.mp4',
#  'data/Phase1/Thang12/13_220448_well02_zid99_PHẠM THUỲ DƯƠNG .mp4': 'data/Phase1/Thang12/13_220448_well02_zid99_3.mp4',
#  'data/Phase1/Thang12/14_220431_well02_zid99_HOÀNG HUYỀN TRANG .mp4': 'data/Phase1/Thang12/14_220431_well02_zid99_4.mp4',
#  'data/Phase1/Thang12/16_220484_well09_zid99_ĐỖ THU HẰNG .mp4': 'data/Phase1/Thang12/16_220484_well09_zid99_5.mp4',
#  'data/Phase1/Thang12/18_220471_well11_zid99_NGUYỄN THUÝ QUỲNH .mp4': 'data/Phase1/Thang12/18_220471_well11_zid99_6.mp4',
#  'data/Phase1/Thang12/19_220427_well10_zid99_TRẦN THỊ PHƯƠNG .mp4': 'data/Phase1/Thang12/19_220427_well10_zid99_7.mp4',
# ...

# %%
import csv
def dict_to_csv(data, filename):
    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Key', 'Value'])
        for key, value in data.items():
            writer.writerow([key, value])
            
dict_to_csv(dict, 'mapping.csv')

# %%
df = pd.read_csv('mapping.csv')

# %%
df
# Out:
#                                                    Key  \
# 0    data/Phase1/Thang12/10_220126_well02_zid99_NG ...
# 1    data/Phase1/Thang12/11_220276A_well10_zid99_NG...
# 2    data/Phase1/Thang12/12_220450_well03_zid99_NG ...
# 3    data/Phase1/Thang12/13_220448_well02_zid99_PHA...
# 4    data/Phase1/Thang12/14_220431_well02_zid99_HOÀ...
# ..                                                 ...
# 110  data/Phase1/Thang4/7-230026_well07_zid99_HOÀN...
# 111  data/Phase1/Thang4/7-230122_well07_zid99_PHẠM...
# 112  data/Phase1/Thang4/8-230119_well08_zid99_BÙI ...
# 113  data/Phase1/Thang4/9-220405_well09_zid99_CHU T...
# 114  data/Phase1/Thang4/9-230038_well09_zid99_NGUYE...
#
#                                                  Value
# 0     data/Phase1/Thang12/10_220126_well02_zid99_0.mp4
# 1    data/Phase1/Thang12/11_220276A_well10_zid99_1.mp4
# 2     data/Phase1/Thang12/12_220450_well03_zid99_2.mp4
# 3     data/Phase1/Thang12/13_220448_well02_zid99_3.mp4
# ...

# %%
# for old_name, new_name in dict.items():
#     os.rename(old_name, new_name)

# %%
import cv2

# Path to the video file
video_path = 'data/Phase1/Thang3/1_220467_well01_zid99_22.mp4'


# Open the video
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Frame rate of the video
frame_rate = cap.get(cv2.CAP_PROP_FPS)

# Interval of frames to capture
interval = int(frame_rate)  # Capturing an image every second

count = 0
frame_count = 0

while cap.isOpened():
    ret, frame = cap.read()

    # If read was successful
    if ret:
        # Save frame every 'interval' frames
        if frame_count % interval == 0:
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            cv2.imwrite(f'img/frame_{count}.jpg', gray)
            count += 1
        frame_count += 1
    else:
        break

# Release the video capture object
cap.release()
cv2.destroyAllWindows()

# %%
frame_rate
# Out:
# 10.0

# %%
import pandas as pd
df = pd.read_excel('data/Phase1/FET AI_v1.xlsx')

# %%
df
# Out:
#      Month.  STT IVF CODE Embryo Freezing\n code          FULL NAME  \
# 0         1    1   220192                 E22181       ĐỒNG KIM ANH
# 1         1    3   220439                 E22410    TRẦN THỊ CHUYÊN
# 2         1    4   220437                 E22412    PHẠM THỊ NGUYỆT
# 3         1    5   220423                 E22401   ĐẶNG THỊ HẢI ANH
# 4         1    6   220384                 E22409       VŨ THỊ DUYÊN
# ..      ...  ...      ...                    ...                ...
# 115       4  157   220483                 E23045  TẠ THỊ MAI PHƯƠNG
# 116       4  159   230138                 E23178       VŨ THỊ DUYÊN
# 117       4  160   230148                 E23193      NGÔ THỊ DUYÊN
# 118       4  161   220455                 E23108    NGUYỄN THỊ LOAN
# 119       4  162   230006                 E23122       LƯU THỊ HOÀI
#
#            DOB             OPU DATE  AGE    ET DATE Thawing date  ...  \
# 0   1994-12-03  2022-07-04 00:00:00   29 2023-01-02   2023-01-02  ...
# ...

# %%
len(df['IVF CODE'].unique())
# Out:
# 116

# %%
value_counts = df['IVF CODE'].value_counts()
duplicated_values_vc = value_counts[value_counts > 1]

# %%
duplicated_values_vc
# Out:
# IVF CODE
# 220276A    2
# 220427     2
# 220417A    2
# 220452     2
# Name: count, dtype: int64

# %%
df['Month.'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df.columns
# Out:
# Index(['Month.', 'STT', 'IVF CODE', 'Embryo Freezing\n code', 'FULL NAME',
#        'DOB', 'OPU DATE', 'AGE', 'ET DATE', 'Thawing date', '1: ET\n2: FET',
#        'Day of Embryo', 'ET times', 'Out of embryo? (Yes: 1/ No: 0)',
#        'No of embryo transferred', 'Embryo quality', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'PGT (YES: 1/ NO: 0)', 'Biopsy code',
#        'Donor eggs (YES: 1/ NO: 0)',
#        'ICSI of thawing oocytes? (YES: 1/ NO: 0)',
#        'Donor embryo? (YES: 1/ NO: 0)', 'Donor sperm (YES: 1/ NO: 0)',
#        'Pesa :1 MESA: 2 TESE: 3 Cryto: 4 ', 'Thawing sperm', 'Note',
#        'TIMELAPSE (1,0)', 'AH (1,0)',
#        'ET procedure (1: Easy, 2: Difficult, 3:Moderate)',
#        'Check catheter \n(1: Clean, 2: Blood, 3: Mucus)', 'Doctor',
#        'β-HCG DATE', 'β-HCG ', 'Result of β-HCG (Possitive: 1/ Negative: 0)',
#        'Chemical pregnancy (0: No, 1:Yes)',
#        'Clinical pregnancy (0: No, 1:Yes)', 'fetar',
# ...

# %%
drop_columns = ['Embryo Freezing\n code', 'FULL NAME',
       'DOB', 'OPU DATE', 'AGE', 'ET DATE', 'Thawing date', '1: ET\n2: FET',
       'Day of Embryo', 'ET times', 'Out of embryo? (Yes: 1/ No: 0)',
       'No of embryo transferred', 'Embryo quality', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'PGT (YES: 1/ NO: 0)', 'Biopsy code',
       'Donor eggs (YES: 1/ NO: 0)',
       'ICSI of thawing oocytes? (YES: 1/ NO: 0)',
       'Donor embryo? (YES: 1/ NO: 0)', 'Donor sperm (YES: 1/ NO: 0)',
       'Pesa :1 MESA: 2 TESE: 3 Cryto: 4 ', 'Thawing sperm', 'Note',
       'TIMELAPSE (1,0)', 'AH (1,0)',
       'ET procedure (1: Easy, 2: Difficult, 3:Moderate)',
       'Check catheter \n(1: Clean, 2: Blood, 3: Mucus)', 'Doctor',
       'β-HCG DATE', 'β-HCG ', 'Result of β-HCG (Possitive: 1/ Negative: 0)',
       'No. of ongoing\n fetal sac', 'Thai lưu', 'Tuần thai lưu', 'GEU',
       '>10W', '12W-14W', '16W-18W', '22W', '32W', 'DỰ KIẾN SINH',
       'KHÂU CTC/ĐẶT VÒNG NÂNG', 'TUỔI \nTHAI KHI SINH', 'CÁCH\nSINH',
       'No of babies', 'Birthweight', 'Unnamed: 54', 'Gender', 'Unnamed: 56',
       'Premature/Term/Full term delivery', 'Unnamed: 58', 'Unnamed: 59',
       ' BIẾN CHỨNG\n SƠ SINH', 'Unnamed: 61', 'fetar', 'Chemical pregnancy (0: No, 1:Yes)']

# %%
df = df.drop(columns=drop_columns)

# %%
df
# Out:
#      Month.  STT IVF CODE  Clinical pregnancy (0: No, 1:Yes)
# 0         1    1   220192                                  1
# 1         1    3   220439                                  0
# 2         1    4   220437                                  1
# 3         1    5   220423                                  1
# 4         1    6   220384                                  1
# ..      ...  ...      ...                                ...
# 115       4  157   220483                                  1
# 116       4  159   230138                                  1
# 117       4  160   230148                                  1
# 118       4  161   220455                                  0
# 119       4  162   230006                                  1
#
# [120 rows x 4 columns]

# %%
df.to_excel('label.xlsx')

# %%
len(glob('data/Phase1/Thang12/*.mp4'))
# Out:
# 20

# %%
df['Month.'] = df['Month.'].replace('1', '12')

# %%
mapping = {1: 12, 2: 12}
df['Month.'] = df['Month.'].map(lambda x: mapping.get(x, x))

# %%
df
# Out:
#      Month.  STT IVF CODE  Clinical pregnancy (0: No, 1:Yes)
# 0        12    1   220192                                  1
# 1        12    3   220439                                  0
# 2        12    4   220437                                  1
# 3        12    5   220423                                  1
# 4        12    6   220384                                  1
# ..      ...  ...      ...                                ...
# 115       4  157   220483                                  1
# 116       4  159   230138                                  1
# 117       4  160   230148                                  1
# 118       4  161   220455                                  0
# 119       4  162   230006                                  1
#
# [120 rows x 4 columns]

# %%
df.to_excel('label.xlsx')

# %%
mapping = {12: 'Thang12', 3: 'Thang3', 4: 'Thang4'}
df['Month.'] = df['Month.'].map(lambda x: mapping.get(x, x))
df.to_excel('label.xlsx')

# %%
from glob import glob

# %%
import cv2

# %%
img = cv2.imread('/mnt/sdb2/DaiLe/CLDNN/img/Thang12/28_220457_well09_zid99_15/Thang12_220457_frame_1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_blurred = cv2.GaussianBlur(gray, (9, 9), 2)
circles = cv2.HoughCircles(
    gray_blurred,  # or use 'edges' for the edge-detected image
    cv2.HOUGH_GRADIENT, 
    dp=1, 
    minDist=20, 
    param1=50, 
    param2=25,  # Lowered to try to detect more circles
    minRadius=0, 
    maxRadius=50
)
if circles is not None:
    circles = np.uint16(np.around(circles))
    for i in circles[0, :]:
        # Draw the outer circle
        cv2.circle(img, (i[0], i[1]), i[2], (0, 255, 0), 2)
        # Draw the center of the circle
        cv2.circle(img, (i[0], i[1]), 2, (0, 0, 255), 3)

# %%
type(circles)
# Out:
# NoneType

# %%
import matplotlib.pyplot as plt 
plt.imshow(img)

# %%
rows = img.shape[0]
circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT, 1, rows / 8,
                            param1=100, param2=30,
                            minRadius=1, maxRadius=30)

# %%
if circles is not None:
    circles = np.uint16(np.around(circles))
    for i in circles[0, :]:
        center = (i[0], i[1])
        # circle center
        cv2.circle(img, center, 1, (0, 100, 100), 3)
        # circle outline
        radius = i[2]
        cv2.circle(img, center, radius, (255, 0, 255), 3)

# %%
plt.imshow(img)

# %%
import cv2
import numpy as np

def detect_incomplete_circle(image_path):
    # Read the image
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (9, 9), 2)
    
    # Edge detection
    edges = cv2.Canny(blurred, 50, 150)
    
    # Hough Circle Transform
    circles = cv2.HoughCircles(
        edges,
        cv2.HOUGH_GRADIENT,
        dp=1,
        minDist=50,
        param1=50,
        param2=30,
        minRadius=20,
        maxRadius=100
    )
    
    if circles is not None:
        circles = np.uint16(np.around(circles))
        for i in circles[0, :]:
            # Draw the outer circle
            cv2.circle(img, (i[0], i[1]), i[2], (0, 255, 0), 2)
            # Draw the center of the circle
            cv2.circle(img, (i[0], i[1]), 2, (0, 0, 255), 3)
    print(type(circles))
    # Display the result
    plt.imshow(img)

# Usage
detect_incomplete_circle('/mnt/sdb2/DaiLe/CLDNN/img/Thang12/28_220457_well09_zid99_15/Thang12_220457_frame_72.jpg')
# Out:
# <class 'NoneType'>
